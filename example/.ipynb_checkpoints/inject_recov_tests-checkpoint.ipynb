# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from mrf import display

import pandas as pd
from astropy.io import fits

from DFDetect import DWFS_mrf, detect
import os


from astropy.modeling.functional_models import Sersic2D
import astropy.units as u
from astropy.convolution import convolve_fft
from scipy.ndimage import zoom
from skimage.measure import block_reduce

#Locations of needed files
band = 'G'
tile_name = 'tile_223.647_-1.424_SloanG'
DF_file = DWFS_mrf.tile_dir + tile_name + '_g.fits'
config_file = '/home/tbm33/projects/packages/DragonflyWideSurvey/df_decals_g.yaml'
decals_g_file = DWFS_mrf.decals_dir + tile_name + '_decals_cutout_g.fits'
decals_r_file = DWFS_mrf.decals_dir + tile_name + '_decals_cutout_r.fits'

# %%
#Rough gauss of UDG-like parameters, Obviously will change these and run a bunch of parameters
ser_ind = 0.75
re_phys = 3*u.kpc
D = 75*u.Mpc
re_ang = (re_phys/D *u.rad).to(u.arcsec).value
re_pix = re_ang / 2.5
mu_e = 25
Zpt = 27#ish
Ie = 10**( (mu_e - 5*np.log10(2.5)- Zpt) / -2.5)
psf_pix = np.load('psf_ex.npy')
zoom_fac = 5
size_pix_DF = int(10*re_pix) + 1
size_zoom = size_pix_DF*5
Xz,Yz = np.meshgrid(np.arange(size_zoom), np.arange(size_zoom))
ser_func = Sersic2D(amplitude = Ie, r_eff = re_pix*zoom_fac, n = ser_ind, x_0 = size_zoom /2., y_0 = size_zoom/2.)
zoom_intr = ser_func(Xz,Yz)
zoom_conv = convolve_fft(zoom_intr, zoom(psf_pix,zoom_fac))
gal_img = block_reduce(zoom_conv, (zoom_fac,zoom_fac), func = np.mean)

# %%
df_fits = fits.open(DF_file)
df_IR= df_fits[0].data.copy()
coord = []
for i in range(100):
    x = np.random.randint(30,920)
    y = np.random.randint(30,920)
    df_IR[x:x+gal_img.shape[0], y:y+gal_img.shape[1]] += gal_img
    coord.append([x,y])

# %%
ind = 8
display.display_single(df_IR[coord[ind][0]-17:coord[ind][0]+51,coord[ind][1]-17:coord[ind][1]+51 ])
plt.show()

# %%
plt.imshow(df_IR-df_data)
plt.show()

# %%
hdu = fits.PrimaryHDU(df_IR)
hdu.header = df_fits[0].header
IR_file = './%s_IR_1.fits'%tile_name
hdu.writeto(IR_file,overwrite = True)

# %%
#You don't need the mast catalog but might be worth downloading if you plan on running on multiple tiles
res_IR = DWFS_mrf.run_mrf_tile(IR_file, band, config_file, './output_IR/', hires_g_file = decals_g_file, hires_r_file = decals_r_file, mast_file = DWFS_mrf.master_mast_catalog, use_two_bands = True,save_fig = True)
# Out:
# using master MAST catalog
# 2021-04-23 16:50:19,266 Running Multi-Resolution Filtering (MRF) on "decals" and "df" images!
# 2021-04-23 16:50:19,273 Subtract BACKVAL=632.7 of Dragonfly image
# 2021-04-23 16:50:19,283 Magnify Dragonfly image with a factor of 3.0:
# 2021-04-23 16:50:21,591 Register high resolution image "/netb/dokkum/data/DWFS/decals_frames/tile_223.647_-1.424_SloanG_decals_cutout_g.fits" with "./tile_223.647_-1.424_SloanG_IR_1.fits"
# 2021-04-23 16:50:36,740 Register high resolution image "/netb/dokkum/data/DWFS/decals_frames/tile_223.647_-1.424_SloanG_decals_cutout_r.fits" with "./tile_223.647_-1.424_SloanG_IR_1.fits"
# 2021-04-23 16:50:51,889 Build flux models on high-resolution images: Blue band
# 2021-04-23 16:50:51,890     - sigma = 2.0, minarea = 5
# 2021-04-23 16:50:51,890     - deblend_cont = 0.00500, deblend_nthres = 32.0
# 2021-04-23 16:50:54,169     - Detect 9784 objects
# 2021-04-23 16:50:58,671 Build flux models on high-resolution images: Red band
# 2021-04-23 16:50:58,672     - sigma = 2.0, minarea = 5
# 2021-04-23 16:50:58,672     - deblend_cont = 0.00500, deblend_nthres = 32.0
# 2021-04-23 16:51:01,299     - Detect 12772 objects
# 2021-04-23 16:51:07,946 Make color correction to blue band, remove artifacts as well
# 2021-04-23 16:51:08,746     - color_term = 0.03
# 2021-04-23 16:51:08,761     - median_color (blue/red) = 0.54158
# 2021-04-23 16:51:10,781 Extract objects from color-corrected high resolution image with:
# 2021-04-23 16:51:10,782     - sigma = 2.0, minarea = 5
# 2021-04-23 16:51:10,783     - deblend_cont = 0.00500, deblend_nthres = 32.0
# 2021-04-23 16:51:12,983     - Detect 9797 objects
# 2021-04-23 16:51:13,288 Remove bright stars from this segmentation map, using SEP results.
# 2021-04-23 16:51:13,289     - Bright star limit = 16
# 2021-04-23 16:51:15,122     - 187 stars removed.
# 2021-04-23 16:51:28,575 Flux model from high resolution image has been built.
# 2021-04-23 16:51:28,622 Build convolving kernel to degrade high resolution image.
# 2021-04-23 16:51:28,874     - Rejected Object 5: flux deviation = 0.962
# 2021-04-23 16:51:29,585     - Rejected Object 24: flux deviation = 1.552
# 2021-04-23 16:51:29,624     - Rejected Object 25: flux deviation = 1.179
# 2021-04-23 16:51:30,521     - You have 47 good stars to generate the median kernel
# 2021-04-23 16:51:30,574     - Convolving image, this could be a bit slow @_@
# 2021-04-23 16:51:33,969     - Removing low-SB objects (SB > 20) from flux model.
# 2021-04-23 16:51:34,087     - Kernel flux = 74.5856071684811
# 2021-04-23 16:51:34,093     - Maximum of flux_model / conv_model = 561066.978
# 2021-04-23 16:51:34,134     - SB limit in counts / pixel = 6.9444
# 2021-04-23 16:51:35,525     - Removed 46 low surface brightness objects from flux model.
# 2021-04-23 16:51:49,292     - Convolving image, this could be a bit slow @_@
# 2021-04-23 16:51:53,960 Compact objects has been subtracted from low-resolution image! Saved as "./output_IR/g_res.fits".
# 2021-04-23 16:51:53,978 Extract objects from compact-object-subtracted low-resolution image with:
# 2021-04-23 16:51:53,979     - sigma = 4.0, minarea = 5
# 2021-04-23 16:51:53,980     - deblend_cont = 0.00500, deblend_nthres = 32.0
# 2021-04-23 16:51:54,101     - Detect 597 objects
# 2021-04-23 16:51:54,120 Stack stars to get PSF model!
# 2021-04-23 16:51:54,120     - Match detected objects with previously discard stars
# 2021-04-23 16:51:54,160     - Get 15 stars to be stacked!
# 2021-04-23 16:51:54,424     - Stars are stacked successfully!
# 2021-04-23 16:51:54,433 Wide-PSF parameters:
# 2021-04-23 16:51:54,433     - n=array([3.44, 2.89, 2.07, 4.  ])
# 2021-04-23 16:51:54,434     - theta=array([   5. ,   64.6,  117.5, 1200. ])
# 2021-04-23 16:51:54,802 Draw star halo models onto the image, and subtract them!
# 2021-04-23 16:52:01,118 Bright star halos are subtracted!
# 2021-04-23 16:52:01,119 Clean the image!
# 2021-04-23 16:52:01,494     - Replace artifacts with void.
# 2021-04-23 16:52:01,692 The final result is saved as "./output_IR/g_final.fits"!
# 2021-04-23 16:52:01,693 The mask is saved as "./output_IR/g_mask.fits"!
# 2021-04-23 16:52:01,694 Delete all temporary files!
# 2021-04-23 16:52:01,777 Determine surface brightness detection limit
# 2021-04-23 16:52:01,779     - Binning factors: dx = 24, dy = 24
# 2021-04-23 16:52:01,779     - Used bin area / True bin area = 1.00000
# 2021-04-23 16:52:02,642     - 1.0-sigma variation in counts = 0.3532 +- 0.0106
# 2021-04-23 16:52:02,643     - 1.0-sigma surface brightness limit on 60 arcsec scale is 30.4198 +- 0.0452
# 2021-04-23 16:52:05,001 Task finished! (⁎⁍̴̛ᴗ⁍̴̛⁎)

# %%
# %matplotlib inline
obj_IR = detect.detect_sources(res_IR.lowres_final.image, 10, 'g',  res_IR.lowres_final.wcs,search_radius = 3., mask = res_IR.lowres_mask.image)
plt.show()

# %%
num_match = 0
for coord_cur in coord:
    is_close = (np.abs(obj_IR['x'] - coord_cur[1]-17) < 1)*( np.abs(obj_IR['y']- (coord_cur[0]+17) ) < 1)
    if np.sum(is_close) == 1:
        num_match += 1
    elif np.sum(is_close) > 1:
        print('More then 1 ?')
print (num_match,'/',len(coord) )
# Out:
# 69 / 100

# %%
print ('frac recoved = %.2f +/- %.2f'%(num_match/len(coord),np.sqrt(num_match)/len(coord)) )
# Out:
# frac recoved = 0.69 +/- 0.08

# %%
frac_masked = np.sum(res_IR.lowres_mask.image)/ (res_IR.lowres_mask.image.shape[0]*res_IR.lowres_mask.image.shape[1] )
1-frac_masked
# Out:
# 0.8056997245695228
